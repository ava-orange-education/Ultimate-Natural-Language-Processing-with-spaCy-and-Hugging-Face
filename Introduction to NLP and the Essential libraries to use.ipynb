# %%
# !pip install spacy
# Out:
# Requirement already satisfied: spacy in c:\users\1508\appdata\local\anaconda30\lib\site-packages (3.7.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\1508\appdata\local\anaconda30\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\1508\appdata\local\anaconda30\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\1508\appdata\local\anaconda30\lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\1508\appdata\local\anaconda30\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\1508\appdata\local\anaconda30\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in c:\users\1508\appdata\local\anaconda30\lib\site-packages (from spacy) (8.2.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\1508\appdata\local\anaconda30\lib\site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\1508\appdata\local\anaconda30\lib\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\1508\appdata\local\anaconda30\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\1508\appdata\local\anaconda30\lib\site-packages (from spacy) (0.3.2)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\1508\appdata\local\anaconda30\lib\site-packages (from spacy) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\1508\appdata\local\anaconda30\lib\site-packages (from spacy) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\1508\appdata\local\anaconda30\lib\site-packages (from spacy) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\1508\appdata\local\anaconda30\lib\site-packages (from spacy) (4.66.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\1508\appdata\roaming\python\python310\site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\1508\appdata\local\anaconda30\lib\site-packages (from spacy) (1.10.12)
# Requirement already satisfied: jinja2 in c:\users\1508\appdata\roaming\python\python310\site-packages (from spacy) (3.1.3)
# Requirement already satisfied: setuptools in c:\users\1508\appdata\roaming\python\python310\site-packages (from spacy) (69.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\1508\appdata\local\anaconda30\lib\site-packages (from spacy) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\1508\appdata\local\anaconda30\lib\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\1508\appdata\local\anaconda30\lib\site-packages (from spacy) (1.23.5)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\1508\appdata\roaming\python\python310\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\1508\appdata\roaming\python\python310\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\1508\appdata\roaming\python\python310\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\1508\appdata\roaming\python\python310\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\1508\appdata\roaming\python\python310\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\1508\appdata\local\anaconda30\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\1508\appdata\local\anaconda30\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.1.3)
# Requirement already satisfied: colorama in c:\users\1508\appdata\roaming\python\python310\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\1508\appdata\roaming\python\python310\site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.16.0,>=0.7.0 in c:\users\1508\appdata\local\anaconda30\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.15.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\1508\appdata\roaming\python\python310\site-packages (from jinja2->spacy) (2.1.5)
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# WARNING: Error parsing requirements for pyqt5-sip: [Errno 2] No such file or directory: 'c:\\users\\1508\\appdata\\local\\anaconda30\\lib\\site-packages\\PyQt5_sip-12.11.0.dist-info\\METADATA'
# WARNING: Error parsing requirements for pyqtwebengine: [Errno 2] No such file or directory: 'c:\\users\\1508\\appdata\\local\\anaconda30\\lib\\site-packages\\PyQtWebEngine-5.15.4.dist-info\\METADATA'
# WARNING: Error parsing requirements for sip: [Errno 2] No such file or directory: 'c:\\users\\1508\\appdata\\local\\anaconda30\\lib\\site-packages\\sip-6.6.2.dist-info\\METADATA'
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\1508\appdata\local\anaconda30\lib\site-packages)

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      - -------------------------------------- 0.5/12.8 MB 10.2 MB/s eta 0:00:02
#      ---- ----------------------------------- 1.5/12.8 MB 15.7 MB/s eta 0:00:01
#      ------- -------------------------------- 2.4/12.8 MB 16.6 MB/s eta 0:00:01
#      ---------- ----------------------------- 3.3/12.8 MB 17.3 MB/s eta 0:00:01
#      ------------ --------------------------- 4.0/12.8 MB 17.2 MB/s eta 0:00:01
#      -------------- ------------------------- 4.8/12.8 MB 16.8 MB/s eta 0:00:01
#      ------------------ --------------------- 5.9/12.8 MB 17.8 MB/s eta 0:00:01
#      -------------------- ------------------- 6.5/12.8 MB 18.1 MB/s eta 0:00:01
#      ----------------------- ---------------- 7.5/12.8 MB 18.4 MB/s eta 0:00:01
#      -------------------------- ------------- 8.4/12.8 MB 18.4 MB/s eta 0:00:01
#      ----------------------------- ---------- 9.3/12.8 MB 18.6 MB/s eta 0:00:01
#      ------------------------------- ------- 10.4/12.8 MB 19.3 MB/s eta 0:00:01
#      ---------------------------------- ---- 11.2/12.8 MB 19.8 MB/s eta 0:00:01
#      ------------------------------------ -- 11.9/12.8 MB 19.9 MB/s eta 0:00:01
#      --------------------------------------  12.8/12.8 MB 19.9 MB/s eta 0:00:01
#      --------------------------------------  12.8/12.8 MB 19.9 MB/s eta 0:00:01
#      --------------------------------------- 12.8/12.8 MB 17.7 MB/s eta 0:00:00
# Collecting spacy<3.8.0,>=3.7.2 (from en-core-web-sm==3.7.1)
#   Downloading spacy-3.7.4-cp310-cp310-win_amd64.whl.metadata (27 kB)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\1508\appdata\local\anaconda30\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\1508\appdata\local\anaconda30\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\1508\appdata\local\anaconda30\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\1508\appdata\local\anaconda30\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\1508\appdata\local\anaconda30\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Collecting thinc<8.3.0,>=8.2.2 (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1)
#   Downloading thinc-8.2.3-cp310-cp310-win_amd64.whl.metadata (15 kB)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\1508\appdata\local\anaconda30\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\1508\appdata\local\anaconda30\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\1508\appdata\local\anaconda30\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\1508\appdata\local\anaconda30\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.2)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\1508\appdata\local\anaconda30\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\1508\appdata\local\anaconda30\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\1508\appdata\local\anaconda30\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\1508\appdata\roaming\python\python310\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\1508\appdata\local\anaconda30\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.10.12)
# Requirement already satisfied: jinja2 in c:\users\1508\appdata\roaming\python\python310\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.3)
# Requirement already satisfied: setuptools in c:\users\1508\appdata\roaming\python\python310\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (69.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\1508\appdata\local\anaconda30\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\1508\appdata\local\anaconda30\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\1508\appdata\local\anaconda30\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.23.5)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\1508\appdata\roaming\python\python310\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\1508\appdata\roaming\python\python310\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\1508\appdata\roaming\python\python310\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\1508\appdata\roaming\python\python310\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\1508\appdata\roaming\python\python310\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\1508\appdata\local\anaconda30\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\1508\appdata\local\anaconda30\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.3)
# Requirement already satisfied: colorama in c:\users\1508\appdata\roaming\python\python310\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\1508\appdata\roaming\python\python310\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.16.0,>=0.7.0 in c:\users\1508\appdata\local\anaconda30\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.15.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\1508\appdata\roaming\python\python310\site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.5)
# Downloading spacy-3.7.4-cp310-cp310-win_amd64.whl (12.1 MB)
#    ---------------------------------------- 0.0/12.1 MB ? eta -:--:--
#    - -------------------------------------- 0.4/12.1 MB 27.3 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.7/12.1 MB 18.6 MB/s eta 0:00:01
#    --------- ------------------------------ 2.8/12.1 MB 19.9 MB/s eta 0:00:01
#    ------------ --------------------------- 3.7/12.1 MB 19.6 MB/s eta 0:00:01
#    -------------- ------------------------- 4.4/12.1 MB 18.9 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.4/12.1 MB 19.1 MB/s eta 0:00:01
#    -------------------- ------------------- 6.2/12.1 MB 19.0 MB/s eta 0:00:01
#    ------------------------ --------------- 7.3/12.1 MB 18.6 MB/s eta 0:00:01
#    -------------------------- ------------- 8.1/12.1 MB 19.2 MB/s eta 0:00:01
#    ------------------------------ --------- 9.2/12.1 MB 19.6 MB/s eta 0:00:01
#    -------------------------------- ------- 9.9/12.1 MB 19.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.8/12.1 MB 20.5 MB/s eta 0:00:01
#    ---------------------------------------  11.9/12.1 MB 19.9 MB/s eta 0:00:01
#    ---------------------------------------  12.1/12.1 MB 19.8 MB/s eta 0:00:01
#    ---------------------------------------- 12.1/12.1 MB 18.2 MB/s eta 0:00:00
# Downloading thinc-8.2.3-cp310-cp310-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ------------------------- -------------- 1.0/1.5 MB 30.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 18.9 MB/s eta 0:00:00
# Installing collected packages: thinc, spacy, en-core-web-sm
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.2.1
#     Uninstalling thinc-8.2.1:
#       Successfully uninstalled thinc-8.2.1
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.7.1
#     Uninstalling spacy-3.7.1:
#       Successfully uninstalled spacy-3.7.1
# Successfully installed en-core-web-sm-3.7.1 spacy-3.7.4 thinc-8.2.3
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# WARNING: Error parsing requirements for pyqt5-sip: [Errno 2] No such file or directory: 'c:\\users\\1508\\appdata\\local\\anaconda30\\lib\\site-packages\\PyQt5_sip-12.11.0.dist-info\\METADATA'
# WARNING: Error parsing requirements for pyqtwebengine: [Errno 2] No such file or directory: 'c:\\users\\1508\\appdata\\local\\anaconda30\\lib\\site-packages\\PyQtWebEngine-5.15.4.dist-info\\METADATA'
# WARNING: Error parsing requirements for sip: [Errno 2] No such file or directory: 'c:\\users\\1508\\appdata\\local\\anaconda30\\lib\\site-packages\\sip-6.6.2.dist-info\\METADATA'
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\1508\AppData\Local\anaconda30\Lib\site-packages\~hinc'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\1508\AppData\Local\anaconda30\Lib\site-packages\~pacy'.
#   You can safely remove it manually.

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

text = "The best video game is Call of Duty, World War 2."
tokens = nlp(text)

for token in tokens:
    print(token.text)
# Out:
# The
# best
# video
# game
# is
# Call
# of
# Duty
# ,
# World
# War
# 2
# .

# %%
text = "The best video game is Call of Duty, World War 2."
tokens = nlp(text)
print(tokens)
# Out:
# The best video game is Call of Duty, World War 2.

# %%
import spacy
from spacy.lang.en.examples import sentences 

nlp = spacy.load("en_core_web_sm")
doc = nlp(sentences[1])
print(doc.text)
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
# Autonomous cars shift insurance liability toward manufacturers
# Autonomous ADJ amod
# cars NOUN nsubj
# shift VERB ROOT
# insurance NOUN compound
# liability NOUN dobj
# toward ADP prep
# manufacturers NOUN pobj

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\1508\appdata\local\anaconda30\lib\site-packages (3.7)
# Requirement already satisfied: click in c:\users\1508\appdata\roaming\python\python310\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\1508\appdata\local\anaconda30\lib\site-packages (from nltk) (1.1.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\1508\appdata\local\anaconda30\lib\site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: tqdm in c:\users\1508\appdata\local\anaconda30\lib\site-packages (from nltk) (4.66.2)
# Requirement already satisfied: colorama in c:\users\1508\appdata\roaming\python\python310\site-packages (from click->nltk) (0.4.6)
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# WARNING: Error parsing requirements for pyqt5-sip: [Errno 2] No such file or directory: 'c:\\users\\1508\\appdata\\local\\anaconda30\\lib\\site-packages\\PyQt5_sip-12.11.0.dist-info\\METADATA'
# WARNING: Error parsing requirements for pyqtwebengine: [Errno 2] No such file or directory: 'c:\\users\\1508\\appdata\\local\\anaconda30\\lib\\site-packages\\PyQtWebEngine-5.15.4.dist-info\\METADATA'
# WARNING: Error parsing requirements for sip: [Errno 2] No such file or directory: 'c:\\users\\1508\\appdata\\local\\anaconda30\\lib\\site-packages\\sip-6.6.2.dist-info\\METADATA'
# WARNING: Ignoring invalid distribution -cipy (c:\users\1508\appdata\local\anaconda30\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\1508\appdata\local\anaconda30\lib\site-packages)

# %% [markdown]
# Stemming

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

def stem_text(text):
    doc = nlp(text)
    stemmed_words = [token.lemma_.lower() for token in doc]  # Use lemma_ for base form
    return " ".join(stemmed_words)

text = "There are five elements that make up life."
stemmed_text = stem_text(text)
print(stemmed_text)  # Output: running race is a fun activit
# Out:
# there be five element that make up life .

# %%
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()

# Example words for stemming
words = ["running", "jumps", "happily", "borrow", "begin"]
 
# Apply stemming to each word
stemmed_words = [stemmer.stem(word) for word in words]
 
# Print the results
print("Original words:", words)
print("Stemmed words:", stemmed_words)
# Out:
# Original words: ['running', 'jumps', 'happily', 'borrow', 'begin']
# Stemmed words: ['run', 'jump', 'happili', 'borrow', 'begin']

# %% [markdown]
# Lemmatization

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

text = "There are five elements that make up life."
doc = nlp(text)

lemmatized_words = [token.lemma_.lower() for token in doc]
lemmatized_text = " ".join(lemmatized_words)
print(lemmatized_text)  # Output: running race is a fun activity
# Out:
# there be five element that make up life .

# %%
import nltk 
from nltk.stem import WordNetLemmatizer 
#nltk.download('punkt')

lemmatizer = WordNetLemmatizer()
 
print("boxes :", lemmatizer.lemmatize("boxes"))
print("universal :", lemmatizer.lemmatize("universal"))
 
# a denotes adjective in "pos"
print("anger :", lemmatizer.lemmatize("angry", pos="a"))
# Out:
# boxes : box
# universal : universal
# anger : angry

# %%
#Stopwords removal

import spacy

nlp = spacy.load("en_core_web_sm")

def remove_stopwords(text):
    stop_words = spacy.lang.en.stop_words.STOP_WORDS
    doc = nlp(text)
    filtered_tokens = [token.text for token in doc if token.text not in stop_words]
    return " ".join(filtered_tokens)

# %%
text = "Natural Language Processing is a very important sub-field in data landscape."
filtered_text = remove_stopwords(text)
print(filtered_text)
# Out:
# Natural Language Processing important sub - field data landscape .

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

text = "Natural Language Processing is a very important sub-field in data landscape."
doc = nlp(text)

filtered_tokens = [token.text for token in doc if not token.is_stop]
filtered_text = " ".join(filtered_tokens)
print(filtered_text)
# Out:
# Natural Language Processing important sub - field data landscape .
